# %% [markdown]
# ## **Libraries**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import requests
from tqdm import tqdm

# %%
import os

base_dir = '/content/drive/MyDrive/GuitarSet'
os.makedirs(base_dir, exist_ok=True)

# %% [markdown]
# ## **Download Dataset**

# %%
files_info = {
    "annotation.zip": "annotation",
    "audio_hex-pickup_debleeded.zip": "audio/hex_pickup_debleeded",
    "audio_hex-pickup_original.zip": "audio/hex_pickup_original",
    "audio_mono-mic.zip": "audio/mono_mic",
    "audio_mono-pickup_mix.zip": "audio/mono_pickup_mix"
}

# %%
base_url = "https://zenodo.org/record/3371780/files/"

for zip_name, folder_name in files_info.items():
    target_folder = os.path.join(base_dir, folder_name)
    os.makedirs(target_folder, exist_ok=True)

    zip_path = f"/content/{zip_name}"
    download_url = f"{base_url}{zip_name}?download=1"

    print(f"\n📥 {zip_name} indiriliyor...")
    # !wget -O "{zip_path}" "{download_url}"

    print(f"📦 {zip_name} çıkarılıyor → {target_folder}")
    # !unzip -q -o "{zip_path}" -d "{target_folder}"
    os.remove(zip_path)

print("\n🎉 Tüm GuitarSet dosyaları başarıyla Drive'a indirildi ve klasörlere çıkarıldı.")
# Out:
# 📥 annotation.zip indiriliyor...
# --2025-05-18 15:30:49--  https://zenodo.org/record/3371780/files/annotation.zip?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.45.92, 188.185.43.25, 188.185.48.194, ...
# Connecting to zenodo.org (zenodo.org)|188.185.45.92|:443... connected.
# HTTP request sent, awaiting response... 301 MOVED PERMANENTLY
# Location: /records/3371780/files/annotation.zip [following]
# --2025-05-18 15:30:50--  https://zenodo.org/records/3371780/files/annotation.zip
# Reusing existing connection to zenodo.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 39132574 (37M) [application/octet-stream]
# Saving to: ‘/content/annotation.zip’
#
# /content/annotation 100%[===================>]  37.32M  3.66MB/s    in 62s
#
# 2025-05-18 15:31:51 (621 KB/s) - ‘/content/annotation.zip’ saved [39132574/39132574]
#
# 📦 annotation.zip çıkarılıyor → /content/drive/MyDrive/GuitarSet/annotation
#
# 📥 audio_hex-pickup_debleeded.zip indiriliyor...
# --2025-05-18 15:32:09--  https://zenodo.org/record/3371780/files/audio_hex-pickup_debleeded.zip?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.43.25, 188.185.48.194, 188.185.45.92, ...
# Connecting to zenodo.org (zenodo.org)|188.185.43.25|:443... connected.
# HTTP request sent, awaiting response... 301 MOVED PERMANENTLY
# Location: /records/3371780/files/audio_hex-pickup_debleeded.zip [following]
# --2025-05-18 15:32:10--  https://zenodo.org/records/3371780/files/audio_hex-pickup_debleeded.zip
# Reusing existing connection to zenodo.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3607349578 (3.4G) [application/octet-stream]
# Saving to: ‘/content/audio_hex-pickup_debleeded.zip’
#
# /content/audio_hex- 100%[===================>]   3.36G  3.27MB/s    in 17m 38s
#
# 2025-05-18 15:49:49 (3.25 MB/s) - ‘/content/audio_hex-pickup_debleeded.zip’ saved [3607349578/3607349578]
#
# 📦 audio_hex-pickup_debleeded.zip çıkarılıyor → /content/drive/MyDrive/GuitarSet/audio/hex_pickup_debleeded
#
# 📥 audio_hex-pickup_original.zip indiriliyor...
# --2025-05-18 15:53:04--  https://zenodo.org/record/3371780/files/audio_hex-pickup_original.zip?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.45.92, 188.185.43.25, 188.185.48.194, ...
# Connecting to zenodo.org (zenodo.org)|188.185.45.92|:443... connected.
# HTTP request sent, awaiting response... 301 MOVED PERMANENTLY
# Location: /records/3371780/files/audio_hex-pickup_original.zip [following]
# --2025-05-18 15:53:05--  https://zenodo.org/records/3371780/files/audio_hex-pickup_original.zip
# Reusing existing connection to zenodo.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3210735945 (3.0G) [application/octet-stream]
# Saving to: ‘/content/audio_hex-pickup_original.zip’
#
# /content/audio_hex- 100%[===================>]   2.99G  12.1MB/s    in 9m 4s
#
# 2025-05-18 16:02:09 (5.63 MB/s) - ‘/content/audio_hex-pickup_original.zip’ saved [3210735945/3210735945]
#
# 📦 audio_hex-pickup_original.zip çıkarılıyor → /content/drive/MyDrive/GuitarSet/audio/hex_pickup_original
#
# 📥 audio_mono-mic.zip indiriliyor...
# --2025-05-18 16:05:24--  https://zenodo.org/record/3371780/files/audio_mono-mic.zip?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.43.25, 188.185.48.194, 188.185.45.92, ...
# Connecting to zenodo.org (zenodo.org)|188.185.43.25|:443... connected.
# HTTP request sent, awaiting response... 301 MOVED PERMANENTLY
# Location: /records/3371780/files/audio_mono-mic.zip [following]
# --2025-05-18 16:05:25--  https://zenodo.org/records/3371780/files/audio_mono-mic.zip
# Reusing existing connection to zenodo.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 656927981 (626M) [application/octet-stream]
# Saving to: ‘/content/audio_mono-mic.zip’
#
# /content/audio_mono 100%[===================>] 626.50M  2.79MB/s    in 7m 36s
#
# 2025-05-18 16:13:01 (1.37 MB/s) - ‘/content/audio_mono-mic.zip’ saved [656927981/656927981]
#
# 📦 audio_mono-mic.zip çıkarılıyor → /content/drive/MyDrive/GuitarSet/audio/mono_mic
#
# 📥 audio_mono-pickup_mix.zip indiriliyor...
# --2025-05-18 16:13:56--  https://zenodo.org/record/3371780/files/audio_mono-pickup_mix.zip?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.48.194, 188.185.45.92, 188.185.43.25, ...
# Connecting to zenodo.org (zenodo.org)|188.185.48.194|:443... connected.
# HTTP request sent, awaiting response... 301 MOVED PERMANENTLY
# Location: /records/3371780/files/audio_mono-pickup_mix.zip [following]
# --2025-05-18 16:13:57--  https://zenodo.org/records/3371780/files/audio_mono-pickup_mix.zip
# Reusing existing connection to zenodo.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 683145360 (651M) [application/octet-stream]
# Saving to: ‘/content/audio_mono-pickup_mix.zip’
#
# /content/audio_mono 100%[===================>] 651.50M  2.80MB/s    in 8m 21s
#
# 2025-05-18 16:22:18 (1.30 MB/s) - ‘/content/audio_mono-pickup_mix.zip’ saved [683145360/683145360]
#
# 📦 audio_mono-pickup_mix.zip çıkarılıyor → /content/drive/MyDrive/GuitarSet/audio/mono_pickup_mix
#
# 🎉 Tüm GuitarSet dosyaları başarıyla Drive'a indirildi ve klasörlere çıkarıldı.

# %% [markdown]
# ## **Inspect Data Set**

# %%
# !pip install numpy==1.24.3
# Out:
# Requirement already satisfied: numpy==1.24.3 in /usr/local/lib/python3.11/dist-packages (1.24.3)

# %%
# !pip install jams
# Out:
# Collecting jams
#   Using cached jams-0.3.4-py3-none-any.whl
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from jams) (2.2.2)
# Requirement already satisfied: sortedcontainers>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from jams) (2.4.0)
# Requirement already satisfied: jsonschema>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from jams) (4.23.0)
# Requirement already satisfied: numpy>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from jams) (1.24.3)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from jams) (1.17.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from jams) (4.4.2)
# Collecting mir-eval>=0.5 (from jams)
#   Using cached mir_eval-0.8.2-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0.0->jams) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0.0->jams) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0.0->jams) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0.0->jams) (0.24.0)
# Requirement already satisfied: scipy>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from mir-eval>=0.5->jams) (1.15.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->jams) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->jams) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->jams) (2025.2)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from referencing>=0.28.4->jsonschema>=3.0.0->jams) (4.13.2)
# Using cached mir_eval-0.8.2-py3-none-any.whl (102 kB)
# Installing collected packages: mir-eval, jams
# Successfully installed jams-0.3.4 mir-eval-0.8.2

# %%
import jams

# %%
import pandas as pd

# %%
import os

jams_dir = "/content/drive/MyDrive/Automatic Guitar Transcription/Data Set/GuitarSet/annotation"

for fname in sorted(os.listdir(jams_dir)):
    if fname.endswith(".jams"):
        print(fname)
# Out:
# 00_BN1-129-Eb_comp.jams
# 00_BN1-129-Eb_solo.jams
# 00_BN1-147-Gb_comp.jams
# 00_BN1-147-Gb_solo.jams
# 00_BN2-131-B_comp.jams
# 00_BN2-131-B_solo.jams
# 00_BN2-166-Ab_comp.jams
# 00_BN2-166-Ab_solo.jams
# 00_BN3-119-G_comp.jams
# 00_BN3-119-G_solo.jams
# 00_BN3-154-E_comp.jams
# 00_BN3-154-E_solo.jams
# 00_Funk1-114-Ab_comp.jams
# 00_Funk1-114-Ab_solo.jams
# 00_Funk1-97-C_comp.jams
# 00_Funk1-97-C_solo.jams
# 00_Funk2-108-Eb_comp.jams
# 00_Funk2-108-Eb_solo.jams
# 00_Funk2-119-G_comp.jams
# 00_Funk2-119-G_solo.jams
# 00_Funk3-112-C#_comp.jams
# 00_Funk3-112-C#_solo.jams
# 00_Funk3-98-A_comp.jams
# 00_Funk3-98-A_solo.jams
# 00_Jazz1-130-D_comp.jams
# 00_Jazz1-130-D_solo.jams
# 00_Jazz1-200-B_comp.jams
# 00_Jazz1-200-B_solo.jams
# 00_Jazz2-110-Bb_comp.jams
# 00_Jazz2-110-Bb_solo.jams
# 00_Jazz2-187-F#_comp.jams
# 00_Jazz2-187-F#_solo.jams
# 00_Jazz3-137-Eb_comp.jams
# 00_Jazz3-137-Eb_solo.jams
# 00_Jazz3-150-C_comp.jams
# 00_Jazz3-150-C_solo.jams
# 00_Rock1-130-A_comp.jams
# 00_Rock1-130-A_solo.jams
# 00_Rock1-90-C#_comp.jams
# 00_Rock1-90-C#_solo.jams
# 00_Rock2-142-D_comp.jams
# 00_Rock2-142-D_solo.jams
# 00_Rock2-85-F_comp.jams
# 00_Rock2-85-F_solo.jams
# 00_Rock3-117-Bb_comp.jams
# 00_Rock3-117-Bb_solo.jams
# 00_Rock3-148-C_comp.jams
# 00_Rock3-148-C_solo.jams
# 00_SS1-100-C#_comp.jams
# 00_SS1-100-C#_solo.jams
# 00_SS1-68-E_comp.jams
# 00_SS1-68-E_solo.jams
# 00_SS2-107-Ab_comp.jams
# 00_SS2-107-Ab_solo.jams
# 00_SS2-88-F_comp.jams
# 00_SS2-88-F_solo.jams
# 00_SS3-84-Bb_comp.jams
# 00_SS3-84-Bb_solo.jams
# 00_SS3-98-C_comp.jams
# 00_SS3-98-C_solo.jams
# 01_BN1-129-Eb_comp.jams
# 01_BN1-129-Eb_solo.jams
# 01_BN1-147-Gb_comp.jams
# 01_BN1-147-Gb_solo.jams
# 01_BN2-131-B_comp.jams
# 01_BN2-131-B_solo.jams
# 01_BN2-166-Ab_comp.jams
# 01_BN2-166-Ab_solo.jams
# 01_BN3-119-G_comp.jams
# 01_BN3-119-G_solo.jams
# 01_BN3-154-E_comp.jams
# 01_BN3-154-E_solo.jams
# 01_Funk1-114-Ab_comp.jams
# 01_Funk1-114-Ab_solo.jams
# 01_Funk1-97-C_comp.jams
# 01_Funk1-97-C_solo.jams
# 01_Funk2-108-Eb_comp.jams
# 01_Funk2-108-Eb_solo.jams
# 01_Funk2-119-G_comp.jams
# 01_Funk2-119-G_solo.jams
# 01_Funk3-112-C#_comp.jams
# 01_Funk3-112-C#_solo.jams
# 01_Funk3-98-A_comp.jams
# 01_Funk3-98-A_solo.jams
# 01_Jazz1-130-D_comp.jams
# 01_Jazz1-130-D_solo.jams
# 01_Jazz1-200-B_comp.jams
# 01_Jazz1-200-B_solo.jams
# 01_Jazz2-110-Bb_comp.jams
# 01_Jazz2-110-Bb_solo.jams
# 01_Jazz2-187-F#_comp.jams
# 01_Jazz2-187-F#_solo.jams
# 01_Jazz3-137-Eb_comp.jams
# 01_Jazz3-137-Eb_solo.jams
# 01_Jazz3-150-C_comp.jams
# 01_Jazz3-150-C_solo.jams
# 01_Rock1-130-A_comp.jams
# 01_Rock1-130-A_solo.jams
# 01_Rock1-90-C#_comp.jams
# 01_Rock1-90-C#_solo.jams
# 01_Rock2-142-D_comp.jams
# 01_Rock2-142-D_solo.jams
# 01_Rock2-85-F_comp.jams
# 01_Rock2-85-F_solo.jams
# 01_Rock3-117-Bb_comp.jams
# 01_Rock3-117-Bb_solo.jams
# 01_Rock3-148-C_comp.jams
# 01_Rock3-148-C_solo.jams
# 01_SS1-100-C#_comp.jams
# 01_SS1-100-C#_solo.jams
# 01_SS1-68-E_comp.jams
# 01_SS1-68-E_solo.jams
# 01_SS2-107-Ab_comp.jams
# 01_SS2-107-Ab_solo.jams
# 01_SS2-88-F_comp.jams
# 01_SS2-88-F_solo.jams
# 01_SS3-84-Bb_comp.jams
# 01_SS3-84-Bb_solo.jams
# 01_SS3-98-C_comp.jams
# 01_SS3-98-C_solo.jams
# 02_BN1-129-Eb_comp.jams
# 02_BN1-129-Eb_solo.jams
# 02_BN1-147-Gb_comp.jams
# 02_BN1-147-Gb_solo.jams
# 02_BN2-131-B_comp.jams
# 02_BN2-131-B_solo.jams
# 02_BN2-166-Ab_comp.jams
# 02_BN2-166-Ab_solo.jams
# 02_BN3-119-G_comp.jams
# 02_BN3-119-G_solo.jams
# 02_BN3-154-E_comp.jams
# 02_BN3-154-E_solo.jams
# 02_Funk1-114-Ab_comp.jams
# 02_Funk1-114-Ab_solo.jams
# 02_Funk1-97-C_comp.jams
# 02_Funk1-97-C_solo.jams
# 02_Funk2-108-Eb_comp.jams
# 02_Funk2-108-Eb_solo.jams
# 02_Funk2-119-G_comp.jams
# 02_Funk2-119-G_solo.jams
# 02_Funk3-112-C#_comp.jams
# 02_Funk3-112-C#_solo.jams
# 02_Funk3-98-A_comp.jams
# 02_Funk3-98-A_solo.jams
# 02_Jazz1-130-D_comp.jams
# 02_Jazz1-130-D_solo.jams
# 02_Jazz1-200-B_comp.jams
# 02_Jazz1-200-B_solo.jams
# 02_Jazz2-110-Bb_comp.jams
# 02_Jazz2-110-Bb_solo.jams
# 02_Jazz2-187-F#_comp.jams
# 02_Jazz2-187-F#_solo.jams
# 02_Jazz3-137-Eb_comp.jams
# 02_Jazz3-137-Eb_solo.jams
# 02_Jazz3-150-C_comp.jams
# 02_Jazz3-150-C_solo.jams
# 02_Rock1-130-A_comp.jams
# 02_Rock1-130-A_solo.jams
# 02_Rock1-90-C#_comp.jams
# 02_Rock1-90-C#_solo.jams
# 02_Rock2-142-D_comp.jams
# 02_Rock2-142-D_solo.jams
# 02_Rock2-85-F_comp.jams
# 02_Rock2-85-F_solo.jams
# 02_Rock3-117-Bb_comp.jams
# 02_Rock3-117-Bb_solo.jams
# 02_Rock3-148-C_comp.jams
# 02_Rock3-148-C_solo.jams
# 02_SS1-100-C#_comp.jams
# 02_SS1-100-C#_solo.jams
# 02_SS1-68-E_comp.jams
# 02_SS1-68-E_solo.jams
# 02_SS2-107-Ab_comp.jams
# 02_SS2-107-Ab_solo.jams
# 02_SS2-88-F_comp.jams
# 02_SS2-88-F_solo.jams
# 02_SS3-84-Bb_comp.jams
# 02_SS3-84-Bb_solo.jams
# 02_SS3-98-C_comp.jams
# 02_SS3-98-C_solo.jams
# 03_BN1-129-Eb_comp.jams
# 03_BN1-129-Eb_solo.jams
# 03_BN1-147-Gb_comp.jams
# 03_BN1-147-Gb_solo.jams
# 03_BN2-131-B_comp.jams
# 03_BN2-131-B_solo.jams
# 03_BN2-166-Ab_comp.jams
# 03_BN2-166-Ab_solo.jams
# 03_BN3-119-G_comp.jams
# 03_BN3-119-G_solo.jams
# 03_BN3-154-E_comp.jams
# 03_BN3-154-E_solo.jams
# 03_Funk1-114-Ab_comp.jams
# 03_Funk1-114-Ab_solo.jams
# 03_Funk1-97-C_comp.jams
# 03_Funk1-97-C_solo.jams
# 03_Funk2-108-Eb_comp.jams
# 03_Funk2-108-Eb_solo.jams
# 03_Funk2-119-G_comp.jams
# 03_Funk2-119-G_solo.jams
# 03_Funk3-112-C#_comp.jams
# 03_Funk3-112-C#_solo.jams
# 03_Funk3-98-A_comp.jams
# 03_Funk3-98-A_solo.jams
# 03_Jazz1-130-D_comp.jams
# 03_Jazz1-130-D_solo.jams
# 03_Jazz1-200-B_comp.jams
# 03_Jazz1-200-B_solo.jams
# 03_Jazz2-110-Bb_comp.jams
# 03_Jazz2-110-Bb_solo.jams
# 03_Jazz2-187-F#_comp.jams
# 03_Jazz2-187-F#_solo.jams
# 03_Jazz3-137-Eb_comp.jams
# 03_Jazz3-137-Eb_solo.jams
# 03_Jazz3-150-C_comp.jams
# 03_Jazz3-150-C_solo.jams
# 03_Rock1-130-A_comp.jams
# 03_Rock1-130-A_solo.jams
# 03_Rock1-90-C#_comp.jams
# 03_Rock1-90-C#_solo.jams
# 03_Rock2-142-D_comp.jams
# 03_Rock2-142-D_solo.jams
# 03_Rock2-85-F_comp.jams
# 03_Rock2-85-F_solo.jams
# 03_Rock3-117-Bb_comp.jams
# 03_Rock3-117-Bb_solo.jams
# 03_Rock3-148-C_comp.jams
# 03_Rock3-148-C_solo.jams
# 03_SS1-100-C#_comp.jams
# 03_SS1-100-C#_solo.jams
# 03_SS1-68-E_comp.jams
# 03_SS1-68-E_solo.jams
# 03_SS2-107-Ab_comp.jams
# 03_SS2-107-Ab_solo.jams
# 03_SS2-88-F_comp.jams
# 03_SS2-88-F_solo.jams
# 03_SS3-84-Bb_comp.jams
# 03_SS3-84-Bb_solo.jams
# 03_SS3-98-C_comp.jams
# 03_SS3-98-C_solo.jams
# 04_BN1-129-Eb_comp.jams
# 04_BN1-129-Eb_solo.jams
# 04_BN1-147-Gb_comp.jams
# 04_BN1-147-Gb_solo.jams
# 04_BN2-131-B_comp.jams
# 04_BN2-131-B_solo.jams
# 04_BN2-166-Ab_comp.jams
# 04_BN2-166-Ab_solo.jams
# 04_BN3-119-G_comp.jams
# 04_BN3-119-G_solo.jams
# 04_BN3-154-E_comp.jams
# 04_BN3-154-E_solo.jams
# 04_Funk1-114-Ab_comp.jams
# 04_Funk1-114-Ab_solo.jams
# 04_Funk1-97-C_comp.jams
# 04_Funk1-97-C_solo.jams
# 04_Funk2-108-Eb_comp.jams
# 04_Funk2-108-Eb_solo.jams
# 04_Funk2-119-G_comp.jams
# 04_Funk2-119-G_solo.jams
# 04_Funk3-112-C#_comp.jams
# 04_Funk3-112-C#_solo.jams
# 04_Funk3-98-A_comp.jams
# 04_Funk3-98-A_solo.jams
# 04_Jazz1-130-D_comp.jams
# 04_Jazz1-130-D_solo.jams
# 04_Jazz1-200-B_comp.jams
# 04_Jazz1-200-B_solo.jams
# 04_Jazz2-110-Bb_comp.jams
# 04_Jazz2-110-Bb_solo.jams
# 04_Jazz2-187-F#_comp.jams
# 04_Jazz2-187-F#_solo.jams
# 04_Jazz3-137-Eb_comp.jams
# 04_Jazz3-137-Eb_solo.jams
# 04_Jazz3-150-C_comp.jams
# 04_Jazz3-150-C_solo.jams
# 04_Rock1-130-A_comp.jams
# 04_Rock1-130-A_solo.jams
# 04_Rock1-90-C#_comp.jams
# 04_Rock1-90-C#_solo.jams
# 04_Rock2-142-D_comp.jams
# 04_Rock2-142-D_solo.jams
# 04_Rock2-85-F_comp.jams
# 04_Rock2-85-F_solo.jams
# 04_Rock3-117-Bb_comp.jams
# 04_Rock3-117-Bb_solo.jams
# 04_Rock3-148-C_comp.jams
# 04_Rock3-148-C_solo.jams
# 04_SS1-100-C#_comp.jams
# 04_SS1-100-C#_solo.jams
# 04_SS1-68-E_comp.jams
# 04_SS1-68-E_solo.jams
# 04_SS2-107-Ab_comp.jams
# 04_SS2-107-Ab_solo.jams
# 04_SS2-88-F_comp.jams
# 04_SS2-88-F_solo.jams
# 04_SS3-84-Bb_comp.jams
# 04_SS3-84-Bb_solo.jams
# 04_SS3-98-C_comp.jams
# 04_SS3-98-C_solo.jams
# 05_BN1-129-Eb_comp.jams
# 05_BN1-129-Eb_solo.jams
# 05_BN1-147-Gb_comp.jams
# 05_BN1-147-Gb_solo.jams
# 05_BN2-131-B_comp.jams
# 05_BN2-131-B_solo.jams
# 05_BN2-166-Ab_comp.jams
# 05_BN2-166-Ab_solo.jams
# 05_BN3-119-G_comp.jams
# 05_BN3-119-G_solo.jams
# 05_BN3-154-E_comp.jams
# 05_BN3-154-E_solo.jams
# 05_Funk1-114-Ab_comp.jams
# 05_Funk1-114-Ab_solo.jams
# 05_Funk1-97-C_comp.jams
# 05_Funk1-97-C_solo.jams
# 05_Funk2-108-Eb_comp.jams
# 05_Funk2-108-Eb_solo.jams
# 05_Funk2-119-G_comp.jams
# 05_Funk2-119-G_solo.jams
# 05_Funk3-112-C#_comp.jams
# 05_Funk3-112-C#_solo.jams
# 05_Funk3-98-A_comp.jams
# 05_Funk3-98-A_solo.jams
# 05_Jazz1-130-D_comp.jams
# 05_Jazz1-130-D_solo.jams
# 05_Jazz1-200-B_comp.jams
# 05_Jazz1-200-B_solo.jams
# 05_Jazz2-110-Bb_comp.jams
# 05_Jazz2-110-Bb_solo.jams
# 05_Jazz2-187-F#_comp.jams
# 05_Jazz2-187-F#_solo.jams
# 05_Jazz3-137-Eb_comp.jams
# 05_Jazz3-137-Eb_solo.jams
# 05_Jazz3-150-C_comp.jams
# 05_Jazz3-150-C_solo.jams
# 05_Rock1-130-A_comp.jams
# 05_Rock1-130-A_solo.jams
# 05_Rock1-90-C#_comp.jams
# 05_Rock1-90-C#_solo.jams
# 05_Rock2-142-D_comp.jams
# 05_Rock2-142-D_solo.jams
# 05_Rock2-85-F_comp.jams
# 05_Rock2-85-F_solo.jams
# 05_Rock3-117-Bb_comp.jams
# 05_Rock3-117-Bb_solo.jams
# 05_Rock3-148-C_comp.jams
# 05_Rock3-148-C_solo.jams
# 05_SS1-100-C#_comp.jams
# 05_SS1-100-C#_solo.jams
# 05_SS1-68-E_comp.jams
# 05_SS1-68-E_solo.jams
# 05_SS2-107-Ab_comp.jams
# 05_SS2-107-Ab_solo.jams
# 05_SS2-88-F_comp.jams
# 05_SS2-88-F_solo.jams
# 05_SS3-84-Bb_comp.jams
# 05_SS3-84-Bb_solo.jams
# 05_SS3-98-C_comp.jams
# 05_SS3-98-C_solo.jams

# %%
import jams

jams_path = "/content/drive/MyDrive/Automatic Guitar Transcription/Data Set/GuitarSet/annotation/03_BN1-129-Eb_solo.jams"
jam = jams.load(jams_path)

for ann in jam.annotations:
    print(f"🧩 Namespace: {ann.namespace} | Count: {len(ann.data)}")
# Out:
# 🧩 Namespace: pitch_contour | Count: 0
# 🧩 Namespace: note_midi | Count: 0
# 🧩 Namespace: pitch_contour | Count: 0
# 🧩 Namespace: note_midi | Count: 0
# 🧩 Namespace: pitch_contour | Count: 435
# 🧩 Namespace: note_midi | Count: 11
# 🧩 Namespace: pitch_contour | Count: 421
# 🧩 Namespace: note_midi | Count: 10
# 🧩 Namespace: pitch_contour | Count: 1131
# 🧩 Namespace: note_midi | Count: 19
# 🧩 Namespace: pitch_contour | Count: 892
# 🧩 Namespace: note_midi | Count: 18
# 🧩 Namespace: beat_position | Count: 48
# 🧩 Namespace: tempo | Count: 1
# 🧩 Namespace: chord | Count: 6
# 🧩 Namespace: chord | Count: 6
# 🧩 Namespace: key_mode | Count: 1

# %%
for ann in jam.annotations:
    print(ann.namespace)
# Out:
# pitch_contour
# note_midi
# pitch_contour
# note_midi
# pitch_contour
# note_midi
# pitch_contour
# note_midi
# pitch_contour
# note_midi
# pitch_contour
# note_midi
# beat_position
# tempo
# chord
# chord
# key_mode

# %%
note_anns = jam.search(namespace='note_midi')
notes = max(note_anns, key=lambda x: len(x.data))

for note in notes:
    print(f"Time: {note.time:.2f}, Duration: {note.duration:.2f}, Pitch (MIDI): {note.value}")
# Out:
# Time: 0.05, Duration: 0.46, Pitch (MIDI): 62.091407982224176
# Time: 1.18, Duration: 0.57, Pitch (MIDI): 62.04842851482689
# Time: 1.90, Duration: 0.15, Pitch (MIDI): 62.06901647771253
# Time: 2.08, Duration: 0.34, Pitch (MIDI): 62.102214177851465
# Time: 2.60, Duration: 0.42, Pitch (MIDI): 62.08156238229204
# Time: 3.03, Duration: 0.32, Pitch (MIDI): 62.09899778717533
# Time: 3.51, Duration: 0.44, Pitch (MIDI): 62.10602929799491
# Time: 3.97, Duration: 0.40, Pitch (MIDI): 62.08227524071211
# Time: 4.44, Duration: 0.41, Pitch (MIDI): 62.093274432400705
# Time: 4.89, Duration: 0.28, Pitch (MIDI): 62.09736484012578
# Time: 5.35, Duration: 0.49, Pitch (MIDI): 62.109933155292126
# Time: 6.31, Duration: 0.41, Pitch (MIDI): 62.100839093336
# Time: 7.47, Duration: 0.57, Pitch (MIDI): 60.07864745586669
# Time: 8.16, Duration: 0.82, Pitch (MIDI): 60.070535002389406
# Time: 9.08, Duration: 0.25, Pitch (MIDI): 60.10351262936211
# Time: 9.58, Duration: 0.43, Pitch (MIDI): 63.09546735976221
# Time: 10.05, Duration: 0.42, Pitch (MIDI): 63.07654022805494
# Time: 10.51, Duration: 0.27, Pitch (MIDI): 63.06284300201546
# Time: 10.96, Duration: 0.41, Pitch (MIDI): 63.09796378009783
# Time: 11.42, Duration: 0.30, Pitch (MIDI): 63.0895735041015
# Time: 11.90, Duration: 0.10, Pitch (MIDI): 62.97674162615182
# Time: 12.36, Duration: 0.24, Pitch (MIDI): 62.0624022256324
# Time: 12.80, Duration: 0.19, Pitch (MIDI): 62.092592331217205
# Time: 13.31, Duration: 0.79, Pitch (MIDI): 62.08413024720747
# Time: 14.45, Duration: 0.22, Pitch (MIDI): 62.0979928282084
# Time: 15.83, Duration: 0.97, Pitch (MIDI): 62.070527174641725
# Time: 17.02, Duration: 0.22, Pitch (MIDI): 59.73766550447657
# Time: 17.71, Duration: 0.51, Pitch (MIDI): 60.05806864171352
# Time: 18.65, Duration: 0.18, Pitch (MIDI): 62.071133235199405
# Time: 19.09, Duration: 0.16, Pitch (MIDI): 62.1048920749643
# Time: 19.29, Duration: 0.28, Pitch (MIDI): 62.103697336295475
# Time: 19.77, Duration: 0.20, Pitch (MIDI): 62.11829133136809
# Time: 20.26, Duration: 0.20, Pitch (MIDI): 62.085827118086065
# Time: 20.70, Duration: 0.21, Pitch (MIDI): 62.11155935514671
# Time: 21.16, Duration: 0.92, Pitch (MIDI): 62.07959774880095
# Time: 22.08, Duration: 0.24, Pitch (MIDI): 62.08507211456887

# %%
import jams

# SOLO ve COMP dosya yollarını gir
solo_path = "/content/drive/MyDrive/Automatic Guitar Transcription/Data Set/GuitarSet/annotation/00_BN1-129-Eb_solo.jams"
comp_path = "/content/drive/MyDrive/Automatic Guitar Transcription/Data Set/GuitarSet/annotation/00_BN1-129-Eb_comp.jams"

def list_jams_annotations(jams_path):
    jam = jams.load(jams_path)
    annotation_summary = []

    for i, ann in enumerate(jam.annotations):
        namespace = ann.namespace
        count = len(ann.data)
        sample = ann.data[0] if count > 0 else None

        annotation_summary.append({
            "namespace": namespace,
            "count": count,
            "example": sample.value if sample else None
        })

    return annotation_summary

# Veri al
solo_annotations = list_jams_annotations(solo_path)
comp_annotations = list_jams_annotations(comp_path)

# Yazdır
print("🎸 SOLO dosyasındaki namespace'ler:\n")
for ann in solo_annotations:
    print(f"🔹 {ann['namespace']} → {ann['count']} veri")
    if ann['example']:
        print(f"   Örnek değer: {ann['example']}\n")

print("\n🎸 COMP dosyasındaki namespace'ler:\n")
for ann in comp_annotations:
    print(f"🔹 {ann['namespace']} → {ann['count']} veri")
    if ann['example']:
        print(f"   Örnek değer: {ann['example']}\n")
# Out:
# 🎸 SOLO dosyasındaki namespace'ler:
#
# 🔹 pitch_contour → 37 veri
#    Örnek değer: {'voiced': True, 'index': 0, 'frequency': 116.45}
#
# 🔹 note_midi → 1 veri
#    Örnek değer: 46.00026427896257
#
# 🔹 pitch_contour → 399 veri
#    Örnek değer: {'voiced': True, 'index': 0, 'frequency': 158.061}
#
# 🔹 note_midi → 7 veri
#    Örnek değer: 51.21675296624269
#
# 🔹 pitch_contour → 1390 veri
#    Örnek değer: {'voiced': True, 'index': 0, 'frequency': 210.364}
#
# 🔹 note_midi → 12 veri
#    Örnek değer: 56.17883958529012
#
# 🔹 pitch_contour → 1896 veri
#    Örnek değer: {'voiced': True, 'index': 0, 'frequency': 296.131}
#
# 🔹 note_midi → 21 veri
#    Örnek değer: 62.10838798559483
#
# 🔹 pitch_contour → 1353 veri
#    Örnek değer: {'voiced': True, 'index': 0, 'frequency': 352.328}
#
# 🔹 note_midi → 24 veri
#    Örnek değer: 65.12288018716855
#
# 🔹 pitch_contour → 291 veri
#    Örnek değer: {'voiced': True, 'index': 0, 'frequency': 468.423}
#
# 🔹 note_midi → 6 veri
#    Örnek değer: 70.05517957978006
#
# 🔹 beat_position → 48 veri
#    Örnek değer: {'position': 1, 'measure': 1, 'num_beats': 4, 'beat_units': 4}
#
# 🔹 tempo → 1 veri
#    Örnek değer: 129.0
#
# 🔹 chord → 6 veri
#    Örnek değer: D#:maj
#
# 🔹 chord → 6 veri
#    Örnek değer: D#:sus2(7)/1
#
# 🔹 key_mode → 1 veri
#    Örnek değer: Eb:major
#
#
# 🎸 COMP dosyasındaki namespace'ler:
#
# 🔹 pitch_contour → 710 veri
#    Örnek değer: {'voiced': True, 'index': 0, 'frequency': 106.492}
#
# 🔹 note_midi → 7 veri
#    Örnek değer: 44.01891665738137
#
# 🔹 pitch_contour → 1964 veri
#    Örnek değer: {'voiced': True, 'index': 0, 'frequency': 155.989}
#
# 🔹 note_midi → 23 veri
#    Örnek değer: 51.036803851780434
#
# 🔹 pitch_contour → 2164 veri
#    Örnek değer: {'voiced': True, 'index': 0, 'frequency': 234.669}
#
# 🔹 note_midi → 33 veri
#    Örnek değer: 58.15072802770881
#
# 🔹 pitch_contour → 2342 veri
#    Örnek değer: {'voiced': True, 'index': 0, 'frequency': 295.282}
#
# 🔹 note_midi → 36 veri
#    Örnek değer: 62.091407982224176
#
# 🔹 pitch_contour → 1648 veri
#    Örnek değer: {'voiced': True, 'index': 0, 'frequency': 349.936}
#
# 🔹 note_midi → 25 veri
#    Örnek değer: 65.04964902107794
#
# 🔹 pitch_contour → 878 veri
#    Örnek değer: {'voiced': True, 'index': 0, 'frequency': 525.982}
#
# 🔹 note_midi → 9 veri
#    Örnek değer: 72.06997378246092
#
# 🔹 beat_position → 48 veri
#    Örnek değer: {'position': 1, 'beat_units': 4, 'measure': 1, 'num_beats': 4}
#
# 🔹 tempo → 1 veri
#    Örnek değer: 129.0
#
# 🔹 chord → 6 veri
#    Örnek değer: D#:maj
#
# 🔹 chord → 6 veri
#    Örnek değer: D#:sus2(7)/1
#
# 🔹 key_mode → 1 veri
#    Örnek değer: Eb:major

# %%
from collections import defaultdict

def group_note_midi_events(jam):
    midi_groups = defaultdict(list)

    for ann in jam.annotations:
        if ann.namespace == "note_midi":
            for note in ann.data:
                midi = round(note.value)  # Float -> int
                midi_groups[midi].append({
                    'start': note.time,
                    'duration': note.duration,
                    'value': note.value
                })

    return midi_groups

# %%
def get_matching_pitch_contours(jam, midi_note, note_events, tolerance=0.05):
    contours = []

    for ann in jam.annotations:
        if ann.namespace == "pitch_contour":
            for pitch in ann.data:
                # Her pitch frame, note zamanına yakın mı?
                for ev in note_events:
                    if abs(pitch.time - ev['start']) < ev['duration'] + tolerance:
                        contours.append({
                            'note': midi_note,
                            'time': pitch.time,
                            'frequency': pitch.value['frequency']
                        })
                        break
    return contours

# %%
# Açık tel MIDI değerleri (standart EADGBE tuning)
OPEN_STRING_MIDI = {
    6: 40,  # E2
    5: 45,  # A2
    4: 50,  # D3
    3: 55,  # G3
    2: 59,  # B3
    1: 64   # E4
}

# %%
import numpy as np

def summarize_fret_string_candidates(midi_note):
    # Yukarıda verdiğimiz OPEN_STRING_MIDI tablosunu kullanalım
    candidates = []
    for string, open_midi in OPEN_STRING_MIDI.items():
        fret = midi_note - open_midi
        if 0 <= fret <= 24:
            freq = librosa.midi_to_hz(open_midi + fret)
            candidates.append((string, fret, round(freq, 2)))
    return candidates

# %%
import librosa

jam = jams.load(solo_path)
midi_groups = group_note_midi_events(jam)

# Örnek: 62
note62_events = midi_groups[62]
pitch_data = get_matching_pitch_contours(jam, 62, note62_events)

# Frekans histogramı
freqs = [p['frequency'] for p in pitch_data]
print(f"🎼 MIDI 62 için ölçülen frekanslar: {np.unique(np.round(freqs, 1))}")

# Muhtemel tel-perde eşlemleri
print(f"🎸 Muhtemel string/fret kombinasyonları:")
for string, fret, freq in summarize_fret_string_candidates(62):
    print(f"String {string}, Fret {fret} → {freq} Hz")
# Out:
# 🎼 MIDI 62 için ölçülen frekanslar: [152.  159.2 167.6 168.  168.1 168.2 168.3 168.6 168.8 169.1 169.4 169.7
#  170.2 171.3 172.6 173.9 174.8 175.5 175.8 175.9 176.  176.1 182.9 191.5
#  196.  196.2 196.3 196.4 196.5 196.8 200.6 210.1 220.  221.  221.1 221.2
#  221.3 221.4 221.5 221.6 221.7 221.8 221.9 222.  222.1 222.2 222.3 222.4
#  223.3 225.7 229.3 229.8 229.9 230.  230.2 230.4 230.5 230.7 230.8 231.8
#  232.9 233.7 233.9 234.  234.1 234.2 234.3 234.4 234.5 234.6 234.7 234.8
#  234.9 235.  235.1 235.2 262.2 262.7 262.8 263.6 263.7 263.8 263.9 264.
#  264.1 264.2 264.3 264.4 264.5 264.8 264.9 265.  265.1 265.2 266.6 267.7
#  280.4 280.6 280.7 280.8 280.9 281.1 281.2 281.3 282.  283.7 284.4 286.3
#  286.6 287.7 288.1 290.4 290.5 291.5 291.8 292.1 292.3 292.8 292.9 293.1
#  293.5 293.6 293.7 293.8 293.9 294.  294.1 294.2 294.3 294.4 294.5 294.6
#  294.7 294.8 294.9 295.  295.1 295.2 295.3 295.4 295.5 295.6 295.7 295.8
#  295.9 296.  296.1 296.2 296.3 296.4 296.5 296.6 296.7 296.8 296.9 297.
#  297.2 297.5 298.  298.1 298.4 298.5 299.4 299.5 299.7 299.9 300.1 300.7
#  302.4 303.1 303.3 303.5 303.7 304.  305.5 305.7 305.8 305.9 306.  306.4
#  306.5 306.9 307.3 307.6 307.8 308.2 308.5 309.3 309.9 310.1 310.5 311.2
#  311.3 311.4 311.6 311.7 311.8 311.9 312.2 312.3 312.4 312.5 312.6 312.7
#  312.8 312.9 313.  313.3 313.4 314.7 315.2 315.9 316.  317.9 321.3 324.3
#  332.9 337.  340.  344.4 347.2 348.7 349.7 349.9 350.2 350.3 350.4 350.5
#  350.6 350.7 350.8 350.9 351.  351.1 351.2 351.3 351.4 351.5 351.6 351.7
#  351.8 351.9 352.  352.1 352.2 352.3 352.4 352.7 352.8 353.2 353.6 354.1
#  354.2 354.9 356.8 357.8 361.3 363.1 364.3 368.4 370.  373.4 380.  383.
#  384.5 386.3 389.6 391.6 393.1 393.7 393.8 393.9 394.  394.1 394.2 394.3
#  394.4 394.5 395.9 396.  465.  466.3 466.5 466.8 467.  467.2 467.3 467.4
#  467.5 467.6 467.7 467.8 467.9 468.  468.1 468.2 468.3 468.4 468.5 471.7
#  472.1 480.4 486.4 495.8 502.7 512.1 518.8 522.2 524.3 525.3 525.5 525.8
#  525.9 526.1 526.2 526.3 526.4 526.5 526.8 527. ]
# 🎸 Muhtemel string/fret kombinasyonları:
# String 6, Fret 22 → 293.66 Hz
# String 5, Fret 17 → 293.66 Hz
# String 4, Fret 12 → 293.66 Hz
# String 3, Fret 7 → 293.66 Hz
# String 2, Fret 3 → 293.66 Hz
