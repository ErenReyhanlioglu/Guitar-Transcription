# %% [markdown]
# ## **Libraries**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

drive_path = "/content/drive/MyDrive/Automatic Guitar Transcription/Data Set/MedleyDB"
os.makedirs(drive_path, exist_ok=True)

# %%
ACCESS_TOKEN = "qlYGWzSGaTxivk5Osj1opZbcpGuaUzPaIKQgJSQCf7agFM41oP9TpjqfebB7"

# %% [markdown]
# ## **Download MedleyDB Dataset**

# %%
# !wget --header="Authorization: Bearer qlYGWzSGaTxivk5Osj1opZbcpGuaUzPaIKQgJSQCf7agFM41oP9TpjqfebB7" \
"https://zenodo.org/api/records/1715175/files/MedleyDB_V2.tar.gz?download=1" \
-O "/content/drive/MyDrive/Automatic Guitar Transcription/Data Set/MedleyDB_V2.tar.gz"
# Out:
# --2025-05-31 10:00:58--  https://zenodo.org/api/records/1715175/files/MedleyDB_V2.tar.gz?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.45.92, 188.185.43.25, 188.185.48.194, ...
# Connecting to zenodo.org (zenodo.org)|188.185.45.92|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 650 [application/json]
# Saving to: ‘/content/drive/MyDrive/Automatic Guitar Transcription/Data Set/MedleyDB_V2.tar.gz’
#
# /content/drive/MyDr 100%[===================>]     650  --.-KB/s    in 0s
#
# 2025-05-31 10:00:59 (380 MB/s) - ‘/content/drive/MyDrive/Automatic Guitar Transcription/Data Set/MedleyDB_V2.tar.gz’ saved [650/650]

# %%
import tarfile

tar_path = f"{drive_path}/MedleyDB_V2.tar.gz"
extract_path = f"{drive_path}/extracted"
os.makedirs(extract_path, exist_ok=True)

with tarfile.open(tar_path, "r:gz") as tar:
    tar.extractall(path=extract_path)
